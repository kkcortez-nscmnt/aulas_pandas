# %% [markdown]
# # Indices Booleanos
#
# Indices Booleanos auxiliam na aplicação de filtros no dataframe

# %%
import pandas as pd
import numpy as np

# %%
file = 'all_seasons.csv'

df = pd.read_csv(file)
df

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'player_name', 'team_abbreviation', 'age',
#        'player_height', 'player_weight', 'college', 'country', 'draft_year',
#        'draft_round', 'draft_number', 'gp', 'pts', 'reb', 'ast', 'net_rating',
#        'oreb_pct', 'dreb_pct', 'usg_pct', 'ts_pct', 'ast_pct', 'season'],
#       dtype='object')

# %%
df['country'].value_counts()
# Out:
# USA           9410
# France         153
# Canada         140
# Spain           79
# Brazil          78
#               ...
# Guinea           1
# Angola           1
# Sudan            1
# Ghana            1
# Sudan (UK)       1
# Name: country, Length: 76, dtype: int64

# %%
 From_Brazil = df['country'] == 'Brazil'
    
From_Brazil.value_counts()
# Out:
# False    11067
# True        78
# Name: country, dtype: int64

# %%
df[From_Brazil]
# Out:
#        Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 3018         3018               Nene               DEN  20.0         210.82
# 3114         3114               Nene               DEN  21.0         210.82
# 3131         3131    Leandro Barbosa               PHX  21.0         190.50
# 3550         3550               Nene               DEN  22.0         210.82
# 3616         3616    Leandro Barbosa               PHX  22.0         190.50
# ...           ...                ...               ...   ...            ...
# 10407       10407          Raul Neto               UTA  27.0         185.42
# 10573       10573               Nene               HOU  36.0         210.82
# 10774       10774      Bruno Caboclo               HOU  24.0         205.74
# 10872       10872  Cristiano Felicio               CHI  27.0         208.28
# 10939       10939          Raul Neto               PHI  27.0         185.42
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'player_name', 'team_abbreviation', 'age',
#        'player_height', 'player_weight', 'college', 'country', 'draft_year',
#        'draft_round', 'draft_number', 'gp', 'pts', 'reb', 'ast', 'net_rating',
#        'oreb_pct', 'dreb_pct', 'usg_pct', 'ts_pct', 'ast_pct', 'season'],
#       dtype='object')

# %%
older_than_30 = df['age']>= 30

df[older_than_30]
# Out:
#        Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0               0      Dennis Rodman               CHI  36.0         198.12
# 2               2       Earl Cureton               TOR  39.0         205.74
# 4               4        Ed Pinckney               MIA  34.0         205.74
# 5               5      Eddie Johnson               HOU  38.0         200.66
# 13             13      Ennis Whatley               POR  34.0         190.50
# ...           ...                ...               ...   ...            ...
# 11122       11122    Marco Belinelli               SAS  33.0         195.58
# 11123       11123  Marcus Morris Sr.               LAC  30.0         203.20
# 11128       11128    Markieff Morris               LAL  30.0         203.20
# 11133       11133    Marvin Williams               MIL  33.0         203.20
# 11134       11134      Mason Plumlee               DEN  30.0         210.82
#
# ...
