# %% [markdown]
# # Exercício de Aplicação
#
# A partir dos dados :https://www.kaggle.com/drgilermo/nba-players-stats, pede-se:
#
# * Qual a média de altura e de peso dos jogaroes?
# * Crie uma nova coluna com a Razão peso/altura dos jogadores.
# * Qual a maior/menor altura, altura ?
# * Qual  a faculdade com maior numero de jogadores?
# * Qual o jogador mais alto ?

# %%
import pandas as pd
import numpy as np

# %%
file = 'all_seasons.csv'
df = pd.read_csv(file)
df.head()
# Out:
#    Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0           0      Dennis Rodman               CHI  36.0         198.12
# 1           1  Dwayne Schintzius               LAC  28.0         215.90
# 2           2       Earl Cureton               TOR  39.0         205.74
# 3           3        Ed O'Bannon               DAL  24.0         203.20
# 4           4        Ed Pinckney               MIA  34.0         205.74
#
#    player_weight                      college country draft_year draft_round  \
# 0      99.790240  Southeastern Oklahoma State     USA       1986           2
# 1     117.933920                      Florida     USA       1990           1
# 2      95.254320                Detroit Mercy     USA       1979           3
# 3     100.697424                         UCLA     USA       1995           1
# 4     108.862080                    Villanova     USA       1985           1
#
# ...

# %%
df.columns
print(df['player_height'].mean())
print(df['player_weight'].mean())
# Out:
# 200.81281830417225
# 100.63786774840734

# %%
razao = df['player_weight']/df['player_height']
print(type(razao))
razao
# Out:
# <class 'pandas.core.series.Series'>
# 0        0.503686
# 1        0.546243
# 2        0.462984
# 3        0.495558
# 4        0.529125
#            ...
# 11140    0.522672
# 11141    0.498631
# 11142    0.552746
# 11143    0.503072
# 11144    0.446449
# Length: 11145, dtype: float64

# %% [markdown]
# # Adicionando uma série ao frame

# %%
df['razao'] = razao
df.head()
# Out:
#    Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0           0      Dennis Rodman               CHI  36.0         198.12
# 1           1  Dwayne Schintzius               LAC  28.0         215.90
# 2           2       Earl Cureton               TOR  39.0         205.74
# 3           3        Ed O'Bannon               DAL  24.0         203.20
# 4           4        Ed Pinckney               MIA  34.0         205.74
#
#    player_weight                      college country draft_year draft_round  \
# 0      99.790240  Southeastern Oklahoma State     USA       1986           2
# 1     117.933920                      Florida     USA       1990           1
# 2      95.254320                Detroit Mercy     USA       1979           3
# 3     100.697424                         UCLA     USA       1995           1
# 4     108.862080                    Villanova     USA       1985           1
#
# ...

# %%
print(df.min())
# Out:
# Unnamed: 0                    0
# player_name          A.C. Green
# team_abbreviation           ATL
# age                        18.0
# player_height            160.02
# player_weight         60.327736
# college
# country                  Angola
# draft_year                 1963
# draft_round                   1
# draft_number                  1
# gp                            1
# pts                         0.0
# reb                         0.0
# ast                         0.0
# net_rating               -200.0
# oreb_pct                    0.0
# dreb_pct                    0.0
# usg_pct                     0.0
# ts_pct                      0.0
# ast_pct                     0.0
# season                  1996-97
# razão                  0.359865
# razao                  0.359865
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'player_name', 'team_abbreviation', 'age',
#        'player_height', 'player_weight', 'college', 'country', 'draft_year',
#        'draft_round', 'draft_number', 'gp', 'pts', 'reb', 'ast', 'net_rating',
#        'oreb_pct', 'dreb_pct', 'usg_pct', 'ts_pct', 'ast_pct', 'season',
#        'razão', 'razao'],
#       dtype='object')

# %%
df['college'].value_counts()
# Out:
# None                         1684
# Kentucky                      360
# Duke                          331
# North Carolina                318
# UCLA                          280
#                              ...
# Louisiana-Monroe                1
# Coppin State                    1
# Manhattan                       1
# North Carolina-Wilmington       1
# Wisconsin-Green Bay             1
# Name: college, Length: 316, dtype: int64

# %%
df.sort_values(by='player_height')
# Out:
#       Unnamed: 0       player_name team_abbreviation   age  player_height  \
# 401          401     Muggsy Bogues               CHH  32.0         160.02
# 1123        1123     Muggsy Bogues               GSW  34.0         160.02
# 2020        2020     Muggsy Bogues               TOR  36.0         160.02
# 483          483     Muggsy Bogues               GSW  33.0         160.02
# 1705        1705     Muggsy Bogues               TOR  35.0         160.02
# ...          ...               ...               ...   ...            ...
# 1053        1053     Shawn Bradley               DAL  27.0         228.60
# 647          647     Shawn Bradley               DAL  26.0         228.60
# 92            92  Gheorghe Muresan               WAS  26.0         231.14
# 1212        1212  Gheorghe Muresan               NJN  28.0         231.14
# 1408        1408  Gheorghe Muresan               NJN  29.0         231.14
#
#       player_weight        college country draft_year draft_round  ...  ast  \
# ...
